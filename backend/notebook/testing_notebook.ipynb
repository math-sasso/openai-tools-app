# %%
import os
import io
import openai
OPENAI_KEY = os.getenv("OPENAI_KEY")
openai.api_key = OPENAI_KEY

# %% [markdown]
# ## Checking DALL-E

# %%
prompt = "Tree deers with natalist clothes"
response = openai.Image.create(
    prompt=prompt,
    model="image-alpha-001",
    size="256x256",
    response_format="url"
)

# %%
url = response["data"][0]["url"]

# %%
import requests
response = requests.get(url)
img = Image.open(io.BytesIO(response.content))
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1024x1024>

# %%
import aiohttp

async with aiohttp.ClientSession() as session:
    async with session.get(url) as resp:
        if resp.status == 200:
            buffer = io.BytesIO(await resp.read())

img = Image.open(buffer)

# %%
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1024x1024>

# %% [markdown]
# ## Checking GPT3

# %%
url = 'https://oaidalleapiprodscus.blob.core.windows.net/private/org-xFxkq2W7W5xOyDkaxbprZ4yl/user-OppN4epsHjDum5Hp0lRxGagh/img-3uEtgCFDuOMnsPf2dgfqTEgh.png?st=2023-04-25T07%3A28%3A50Z&se=2023-04-25T09%3A28%3A50Z&sp=r&sv=2021-08-06&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2023-04-25T08%3A13%3A25Z&ske=2023-04-26T08%3A13%3A25Z&sks=b&skv=2021-08-06&sig=hVINhCrf82%2BhxZVLpIshJwblAufXX5IqzUn5ydsZruA%3D'
async with aiohttp.ClientSession() as session:
        async with session.get(url) as resp:
            if resp.status == 200:
                buffer = io.BytesIO(await resp.read())
                image =  Image.open(buffer)
image
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=256x256>
